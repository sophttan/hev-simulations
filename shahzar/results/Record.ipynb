# %%
import numpy as np
import pandas as pd
from scipy import stats

from matplotlib import pyplot as plt
from matplotlib.patches import Patch

import plotly.express as px
import plotly.graph_objects as go

from IPython.display import HTML
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# # What
# # 7 February

# %%
# 0% Person-to-Person
vals = np.genfromtxt('../50/0/vals_05.txt')
full_Ts_05[0] = vals[:2500, 0]
full_Hs_05[0] = vals[:2500, 1]
full_Rs_05[0] = vals[:2500, 2]

vals = np.genfromtxt('../53/0/vals_05.txt')
part_Hs_05[0] = vals[:, 1]
part_Rs_05[0] = vals[:, 2]

# 25% Person-to-Person
vals = np.genfromtxt('../50/25/vals_05.txt')
full_Ts_05[1] = vals[:2500, 0]
full_Hs_05[1] = vals[:2500, 1]
full_Rs_05[1] = vals[:2500, 2]

vals = np.genfromtxt('../53/25/vals_05.txt')
part_Hs_05[1] = vals[:, 1]
part_Rs_05[1] = vals[:, 2]

# 50% Person-to-Person
vals = np.genfromtxt('../50/50/vals_05.txt')
full_Ts_05[2] = vals[:2500, 0]
full_Hs_05[2] = vals[:2500, 1]
full_Rs_05[2] = vals[:2500, 2]

vals = np.genfromtxt('../53/50/vals_05.txt')
part_Hs_05[2] = vals[:, 1]
part_Rs_05[2] = vals[:, 2]

# 75% Person-to-Person
vals = np.genfromtxt('../50/75/vals_05.txt')
full_Ts_05[3] = vals[:2500, 0]
full_Hs_05[3] = vals[:2500, 1]
full_Rs_05[3] = vals[:2500, 2]

vals = np.genfromtxt('../53/75/vals_05.txt')
part_Hs_05[3] = vals[:, 1]
part_Rs_05[3] = vals[:, 2]

# 100% Person-to-Person
vals = np.genfromtxt('../50/100/vals_05.txt')
full_Ts_05[4] = vals[:2500, 0]
full_Hs_05[4] = vals[:2500, 1]
full_Rs_05[4] = vals[:2500, 2]

vals = np.genfromtxt('../53/100/vals_05.txt')
part_Hs_05[4] = vals[:, 1]
part_Rs_05[4] = vals[:, 2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 3
#       1 # 0% Person-to-Person
#       2 vals = np.genfromtxt('../50/0/vals_05.txt')
# ----> 3 full_Ts_05[0] = vals[:2500, 0]
#       4 full_Hs_05[0] = vals[:2500, 1]
#       5 full_Rs_05[0] = vals[:2500, 2]
#
# NameError: name 'full_Ts_05' is not defined

# %% [markdown]
# ### 10% Incidence

# %%
# 0% Person-to-Person
vals = np.genfromtxt('../50/0/vals_10.txt')
full_Ts_10[0] = vals[:2500, 0]
full_Hs_10[0] = vals[:2500, 1]
full_Rs_10[0] = vals[:2500, 2]

vals = np.genfromtxt('../53/0/vals_10.txt')
part_Hs_10[0] = vals[:, 1]
part_Rs_10[0] = vals[:, 2]

# 25% Person-to-Person
vals = np.genfromtxt('../50/25/vals_10.txt')
full_Ts_10[1] = vals[:2500, 0]
full_Hs_10[1] = vals[:2500, 1]
full_Rs_10[1] = vals[:2500, 2]

vals = np.genfromtxt('../53/25/vals_10.txt')
part_Hs_10[1] = vals[:, 1]
part_Rs_10[1] = vals[:, 2]

# 50% Person-to-Person
vals = np.genfromtxt('../50/50/vals_10.txt')
full_Ts_10[2] = vals[:2500, 0]
full_Hs_10[2] = vals[:2500, 1]
full_Rs_10[2] = vals[:2500, 2]

vals = np.genfromtxt('../53/50/vals_10.txt')
part_Hs_10[2] = vals[:, 1]
part_Rs_10[2] = vals[:, 2]

# 75% Person-to-Person
vals = np.genfromtxt('../50/75/vals_10.txt')
full_Ts_10[3] = vals[:2500, 0]
full_Hs_10[3] = vals[:2500, 1]
full_Rs_10[3] = vals[:2500, 2]

vals = np.genfromtxt('../53/75/vals_10.txt')
part_Hs_10[3] = vals[:, 1]
part_Rs_10[3] = vals[:, 2]

# 100% Person-to-Person
vals = np.genfromtxt('../50/100/vals_10.txt')
full_Ts_10[4] = vals[:2500, 0]
full_Hs_10[4] = vals[:2500, 1]
full_Rs_10[4] = vals[:2500, 2]

vals = np.genfromtxt('../53/100/vals_10.txt')
part_Hs_10[4] = vals[:, 1]
part_Rs_10[4] = vals[:, 2]

# %% [markdown]
# ### 30% Incidence

# %%
# 0% Person-to-Person
vals = np.genfromtxt('../50/0/vals_30.txt')
full_Ts_30[0] = vals[:2500, 0]
full_Hs_30[0] = vals[:2500, 1]
full_Rs_30[0] = vals[:2500, 2]

vals = np.genfromtxt('../53/0/vals_30.txt')
part_Hs_30[0] = vals[:, 1]
part_Rs_30[0] = vals[:, 2]

# 25% Person-to-Person
vals = np.genfromtxt('../50/25/vals_30.txt')
full_Ts_30[1] = vals[:2500, 0]
full_Hs_30[1] = vals[:2500, 1]
full_Rs_30[1] = vals[:2500, 2]

vals = np.genfromtxt('../53/25/vals_30.txt')
part_Hs_30[1] = vals[:, 1]
part_Rs_30[1] = vals[:, 2]

# 50% Person-to-Person
vals = np.genfromtxt('../50/50/vals_30.txt')
full_Ts_30[2] = vals[:2500, 0]
full_Hs_30[2] = vals[:2500, 1]
full_Rs_30[2] = vals[:2500, 2]

vals = np.genfromtxt('../53/50/vals_30.txt')
part_Hs_30[2] = vals[:, 1]
part_Rs_30[2] = vals[:, 2]

# 75% Person-to-Person
vals = np.genfromtxt('../50/75/vals_30.txt')
full_Ts_30[3] = vals[:2500, 0]
full_Hs_30[3] = vals[:2500, 1]
full_Rs_30[3] = vals[:2500, 2]

vals = np.genfromtxt('../53/75/vals_30.txt')
part_Hs_30[3] = vals[:, 1]
part_Rs_30[3] = vals[:, 2]

# 100% Person-to-Person
vals = np.genfromtxt('../50/100/vals_30.txt')
full_Ts_30[4] = vals[:2500, 0]
full_Hs_30[4] = vals[:2500, 1]
full_Rs_30[4] = vals[:2500, 2]

vals = np.genfromtxt('../53/100/vals_30.txt')
part_Hs_30[4] = vals[:, 1]
part_Rs_30[4] = vals[:, 2]

# %% [markdown]
# ## Middle Percentiles

# %%
# 5% Incidence
lo_full_T_05 = np.percentile(full_Ts_05, 2.5, axis = 1)
md_full_T_05 = np.percentile(full_Ts_05, 50, axis = 1)
hi_full_T_05 = np.percentile(full_Ts_05, 97.5, axis = 1)

lo_full_H_05 = np.percentile(full_Hs_05, 2.5, axis = 1)
md_full_H_05 = np.percentile(full_Hs_05, 50, axis = 1)
hi_full_H_05 = np.percentile(full_Hs_05, 97.5, axis = 1)

lo_full_R_05 = np.percentile(full_Rs_05, 2.5, axis = 1)
md_full_R_05 = np.percentile(full_Rs_05, 50, axis = 1)
hi_full_R_05 = np.percentile(full_Rs_05, 97.5, axis = 1)

lo_part_H_05 = np.percentile(part_Hs_05, 2.5, axis = 1)
md_part_H_05 = np.percentile(part_Hs_05, 50, axis = 1)
hi_part_H_05 = np.percentile(part_Hs_05, 97.5, axis = 1)

lo_part_R_05 = np.percentile(part_Rs_05, 2.5, axis = 1)
md_part_R_05 = np.percentile(part_Rs_05, 50, axis = 1)
hi_part_R_05 = np.percentile(part_Rs_05, 97.5, axis = 1)


# 10% Incidence
lo_full_T_10 = np.percentile(full_Ts_10, 2.5, axis = 1)
md_full_T_10 = np.percentile(full_Ts_10, 50, axis = 1)
hi_full_T_10 = np.percentile(full_Ts_10, 97.5, axis = 1)

lo_full_H_10 = np.percentile(full_Hs_10, 2.5, axis = 1)
md_full_H_10 = np.percentile(full_Hs_10, 50, axis = 1)
hi_full_H_10 = np.percentile(full_Hs_10, 97.5, axis = 1)

lo_full_R_10 = np.percentile(full_Rs_10, 2.5, axis = 1)
md_full_R_10 = np.percentile(full_Rs_10, 50, axis = 1)
hi_full_R_10 = np.percentile(full_Rs_10, 97.5, axis = 1)

lo_part_H_10 = np.percentile(part_Hs_10, 2.5, axis = 1)
md_part_H_10 = np.percentile(part_Hs_10, 50, axis = 1)
hi_part_H_10 = np.percentile(part_Hs_10, 97.5, axis = 1)

lo_part_R_10 = np.percentile(part_Rs_10, 2.5, axis = 1)
md_part_R_10 = np.percentile(part_Rs_10, 50, axis = 1)
hi_part_R_10 = np.percentile(part_Rs_10, 97.5, axis = 1)


# 30% Incidence
lo_full_T_30 = np.percentile(full_Ts_30, 2.5, axis = 1)
md_full_T_30 = np.percentile(full_Ts_30, 50, axis = 1)
hi_full_T_30 = np.percentile(full_Ts_30, 97.5, axis = 1)

lo_full_H_30 = np.percentile(full_Hs_30, 2.5, axis = 1)
md_full_H_30 = np.percentile(full_Hs_30, 50, axis = 1)
hi_full_H_30 = np.percentile(full_Hs_30, 97.5, axis = 1)

lo_full_R_30 = np.percentile(full_Rs_30, 2.5, axis = 1)
md_full_R_30 = np.percentile(full_Rs_30, 50, axis = 1)
hi_full_R_30 = np.percentile(full_Rs_30, 97.5, axis = 1)

lo_part_H_30 = np.percentile(part_Hs_30, 2.5, axis = 1)
md_part_H_30 = np.percentile(part_Hs_30, 50, axis = 1)
hi_part_H_30 = np.percentile(part_Hs_30, 97.5, axis = 1)

lo_part_R_30 = np.percentile(part_Rs_30, 2.5, axis = 1)
md_part_R_30 = np.percentile(part_Rs_30, 50, axis = 1)
hi_part_R_30 = np.percentile(part_Rs_30, 97.5, axis = 1)

# %%
vals_05_pan = np.genfromtxt('pan/vals_05.txt').mean(axis = 0)
vals_05_025 = np.genfromtxt('25/vals_05.txt').mean(axis = 0)
vals_05_050 = np.genfromtxt('50/vals_05.txt').mean(axis = 0)
vals_05_075 = np.genfromtxt('75/vals_05.txt').mean(axis = 0)
vals_05_100 = np.genfromtxt('100/vals_05.txt').mean(axis = 0)

vals_10_pan = np.genfromtxt('pan/vals_10.txt').mean(axis = 0)
vals_10_025 = np.genfromtxt('25/vals_10.txt').mean(axis = 0)
vals_10_050 = np.genfromtxt('50/vals_10.txt').mean(axis = 0)
vals_10_075 = np.genfromtxt('75/vals_10.txt').mean(axis = 0)
vals_10_100 = np.genfromtxt('100/vals_10.txt').mean(axis = 0)

vals_30_pan = np.genfromtxt('pan/vals_30.txt').mean(axis = 0)
vals_30_025 = np.genfromtxt('25/vals_30.txt').mean(axis = 0)
vals_30_050 = np.genfromtxt('50/vals_30.txt').mean(axis = 0)
vals_30_075 = np.genfromtxt('75/vals_30.txt').mean(axis = 0)
vals_30_100 = np.genfromtxt('100/vals_30.txt').mean(axis = 0)

# %%
fig, axs = plt.subplots(1, 3, sharex = True, sharey = True, figsize = (9, 3))
ptps = [0, 0.25, 0.50, 0.75, 1]
plt.xlim(0, 1)
plt.ylim(0, 0.25)

# 5% Incidence
y_05_1 = [vals_05_pan[0], vals_05_025[0], vals_05_050[0], vals_05_075[0], vals_05_100[0]]
y_05_2 = [vals_05_pan[1], vals_05_025[1], vals_05_050[1], vals_05_075[1], vals_05_100[1]]
y_05_5 = [vals_05_pan[2], vals_05_025[2], vals_05_050[2], vals_05_075[2], vals_05_100[2]]

axs[0].plot(prp, y_05_1, marker = '.', color = 'dodgerblue', label = 'rel_p_hh = 1')
axs[0].plot(prp, y_05_2, marker = '.', color = 'crimson', label = 'rel_p_hh = 2')
axs[0].plot(prp, y_05_5, marker = '.', color = 'forestgreen', label = 'rel_p_hh = 5')
axs[0].grid()
axs[0].set_title(r'5% Incidence', loc = 'left', size = 10)
axs[0].set_ylabel(r'$R_{\rm HH}/R$')

# 10% Incidence
y_10_1 = [vals_10_pan[0], vals_10_025[0], vals_10_050[0], vals_10_075[0], vals_10_100[0]]
y_10_2 = [vals_10_pan[1], vals_10_025[1], vals_10_050[1], vals_10_075[1], vals_10_100[1]]
y_10_5 = [vals_10_pan[2], vals_10_025[2], vals_10_050[2], vals_10_075[2], vals_10_100[2]]

axs[1].plot(prp, y_10_1, marker = '.', color = 'dodgerblue', label = 'rel_p_hh = 1')
axs[1].plot(prp, y_10_2, marker = '.', color = 'crimson', label = 'rel_p_hh = 2')
axs[1].plot(prp, y_10_5, marker = '.', color = 'forestgreen', label = 'rel_p_hh = 5')
axs[1].grid()
axs[1].set_title(r'10% Incidence', loc = 'left', size = 10)

# 30% Incidence
y_30_1 = [vals_30_pan[0], vals_30_025[0], vals_30_050[0], vals_30_075[0], vals_30_100[0]]
y_30_2 = [vals_30_pan[1], vals_30_025[1], vals_30_050[1], vals_30_075[1], vals_30_100[1]]
y_30_5 = [vals_30_pan[2], vals_30_025[2], vals_30_050[2], vals_30_075[2], vals_30_100[2]]

axs[2].plot(prp, y_30_1, marker = '.', color = 'dodgerblue', label = 'rel_p_hh = 1')
axs[2].plot(prp, y_30_2, marker = '.', color = 'crimson', label = 'rel_p_hh = 2')
axs[2].plot(prp, y_30_5, marker = '.', color = 'forestgreen', label = 'rel_p_hh = 5')
axs[2].grid()
axs[2].set_title(r'30% Incidence', loc = 'left', size = 10)

fig.text(0.5, -0.03, r'Person-to-Person Transmission', ha='center')

handles, labels = axs[0].get_legend_handles_labels()
fig.legend(handles, labels, bbox_to_anchor = (0.78, -0.05), frameon = False, ncol = 3)
fig.tight_layout()

# x-axis with proportion of household cases instead of person-to-person transmission

# %%
vals_05_pan = np.genfromtxt('pan/vals_05_idc.txt').mean(axis = 0)
vals_05_025 = np.genfromtxt('25/vals_05_idc.txt').mean(axis = 0)
vals_05_050 = np.genfromtxt('50/vals_05_idc.txt').mean(axis = 0)
vals_05_075 = np.genfromtxt('75/vals_05_idc.txt').mean(axis = 0)
vals_05_100 = np.genfromtxt('100/vals_05_idc.txt').mean(axis = 0)

vals_10_pan = np.genfromtxt('pan/vals_10_idc.txt').mean(axis = 0)
vals_10_025 = np.genfromtxt('25/vals_10_idc.txt').mean(axis = 0)
vals_10_050 = np.genfromtxt('50/vals_10_idc.txt').mean(axis = 0)
vals_10_075 = np.genfromtxt('75/vals_10_idc.txt').mean(axis = 0)
vals_10_100 = np.genfromtxt('100/vals_10_idc.txt').mean(axis = 0)

vals_30_pan = np.genfromtxt('pan/vals_30_idc.txt').mean(axis = 0)
vals_30_025 = np.genfromtxt('25/vals_30_idc.txt').mean(axis = 0)
vals_30_050 = np.genfromtxt('50/vals_30_idc.txt').mean(axis = 0)
vals_30_075 = np.genfromtxt('75/vals_30_idc.txt').mean(axis = 0)
vals_30_100 = np.genfromtxt('100/vals_30_idc.txt').mean(axis = 0)

# %%
fig, axs = plt.subplots(1, 3, sharex = True, sharey = True, figsize = (9, 3))
ptps = [0, 0.25, 0.50, 0.75, 1]
plt.xlim(0, 1)
plt.ylim(0, 0.25)

# 5% Incidence
y_05_idc = [vals_05_pan, vals_05_025, vals_05_050, vals_05_075, vals_05_100]

axs[0].plot(prp, y_05_1, marker = '.', color = 'crimson', label = r'rel_p_hh = 1')
axs[0].plot(prp, y_05_idc, marker = '.', color = 'dodgerblue', label = r'rel_p_hh = $\frac{1}{1 - {\rm idc}}$')
axs[0].grid()
axs[0].set_title(r'5% Incidence', loc = 'left', size = 10)
axs[0].set_ylabel('Proportion of \nHousehold Cases')

# 10% Incidence
y_10_idc = [vals_10_pan, vals_10_025, vals_10_050, vals_10_075, vals_10_100]

axs[1].plot(prp, y_10_1, marker = '.', color = 'crimson', label = r'rel_p_hh = 1')
axs[1].plot(prp, y_10_idc, marker = '.', color = 'dodgerblue', label = r'rel_p_hh = $\frac{1}{1 - {\rm idc}}$')
axs[1].grid()
axs[1].set_title(r'10% Incidence', loc = 'left', size = 10)

# 30% Incidence
y_30_idc = [vals_30_pan, vals_30_025, vals_30_050, vals_30_075, vals_30_100]

axs[2].plot(prp, y_30_1, marker = '.', color = 'crimson', label = r'rel_p_hh = 1')
axs[2].plot(prp, y_30_idc, marker = '.', color = 'dodgerblue', label = r'rel_p_hh = $\frac{1}{1 - {\rm idc}}$')
axs[2].grid()
axs[2].set_title(r'30% Incidence', loc = 'left', size = 10)

fig.text(0.5, -0.03, 'Person-to-Person Transmission', ha='center')

handles, labels = axs[0].get_legend_handles_labels()
fig.legend(handles, labels, bbox_to_anchor = (0.65, -0.05), frameon = False, ncol = 3)
fig.tight_layout()

# %% [markdown]
# # 21 February 2024

# %%
vals_05_pan = np.genfromtxt('54/pan/R_HH_05.txt').mean(axis = 0)
vals_05_025 = np.genfromtxt('54/25/R_HH_05.txt').mean(axis = 0)
vals_05_050 = np.genfromtxt('54/50/R_HH_05.txt').mean(axis = 0)
vals_05_075 = np.genfromtxt('54/75/R_HH_05.txt').mean(axis = 0)
vals_05_100 = np.genfromtxt('54/100/R_HH_05.txt').mean(axis = 0)

vals_10_pan = np.genfromtxt('54/pan/R_HH_10.txt').mean(axis = 0)
vals_10_025 = np.genfromtxt('54/25/R_HH_10.txt').mean(axis = 0)
vals_10_050 = np.genfromtxt('54/50/R_HH_10.txt').mean(axis = 0)
vals_10_075 = np.genfromtxt('54/75/R_HH_10.txt').mean(axis = 0)
vals_10_100 = np.genfromtxt('54/100/R_HH_10.txt').mean(axis = 0)

vals_30_pan = np.genfromtxt('54/pan/R_HH_30.txt').mean(axis = 0)
vals_30_025 = np.genfromtxt('54/25/R_HH_30.txt').mean(axis = 0)
vals_30_050 = np.genfromtxt('54/50/R_HH_30.txt').mean(axis = 0)
vals_30_075 = np.genfromtxt('54/75/R_HH_30.txt').mean(axis = 0)
vals_30_100 = np.genfromtxt('54/100/R_HH_30.txt').mean(axis = 0)

# %%
fig, axs = plt.subplots(1, 3, sharex = True, sharey = True, figsize = (9, 3))
prp = [0, 0.25, 0.50, 0.75, 1]
plt.xlim(0, 1)
plt.ylim(0, 0.15)

# 5% Incidence
y_05_idc = [vals_05_pan, vals_05_025, vals_05_050, vals_05_075, vals_05_100]

#axs[0].plot(prp, y_05_1, marker = '.', color = 'crimson', label = r'rel_p_hh = 1')
axs[0].plot(prp, y_05_idc, marker = '.', color = 'dodgerblue', label = r'$R_{\rm HH}$')
axs[0].grid()
axs[0].set_title(r'5% Incidence', loc = 'left', size = 10)
axs[0].set_ylabel(r'$R_{\rm HH}$')

# 10% Incidence
y_10_idc = [vals_10_pan, vals_10_025, vals_10_050, vals_10_075, vals_10_100]

#axs[1].plot(prp, y_10_1, marker = '.', color = 'crimson', label = r'rel_p_hh = 1')
axs[1].plot(prp, y_10_idc, marker = '.', color = 'dodgerblue', label = r'$R_{\rm HH}$')
axs[1].grid()
axs[1].set_title(r'10% Incidence', loc = 'left', size = 10)

# 30% Incidence
y_30_idc = [vals_30_pan, vals_30_025, vals_30_050, vals_30_075, vals_30_100]

#axs[2].plot(prp, y_30_1, marker = '.', color = 'crimson', label = r'rel_p_hh = 1')
axs[2].plot(prp, y_30_idc, marker = '.', color = 'dodgerblue', label = r'$R_{\rm HH}$')
axs[2].grid()
axs[2].set_title(r'30% Incidence', loc = 'left', size = 10)

fig.text(0.5, -0.03, 'Person-to-Person Transmission', ha='center')

handles, labels = axs[0].get_legend_handles_labels()
fig.legend(handles, labels, bbox_to_anchor = (0.65, -0.05), frameon = False, ncol = 3)
fig.tight_layout()

# %%
vals_05_pan = np.genfromtxt('54/pan/R_05.txt').mean(axis = 0)
vals_05_025 = np.genfromtxt('54/25/R_05.txt').mean(axis = 0)
vals_05_050 = np.genfromtxt('54/50/R_05.txt').mean(axis = 0)
vals_05_075 = np.genfromtxt('54/75/R_05.txt').mean(axis = 0)
vals_05_100 = np.genfromtxt('54/100/R_05.txt').mean(axis = 0)

vals_10_pan = np.genfromtxt('54/pan/R_10.txt').mean(axis = 0)
vals_10_025 = np.genfromtxt('54/25/R_10.txt').mean(axis = 0)
vals_10_050 = np.genfromtxt('54/50/R_10.txt').mean(axis = 0)
vals_10_075 = np.genfromtxt('54/75/R_10.txt').mean(axis = 0)
vals_10_100 = np.genfromtxt('54/100/R_10.txt').mean(axis = 0)

vals_30_pan = np.genfromtxt('54/pan/R_30.txt').mean(axis = 0)
vals_30_025 = np.genfromtxt('54/25/R_30.txt').mean(axis = 0)
vals_30_050 = np.genfromtxt('54/50/R_30.txt').mean(axis = 0)
vals_30_075 = np.genfromtxt('54/75/R_30.txt').mean(axis = 0)
vals_30_100 = np.genfromtxt('54/100/R_30.txt').mean(axis = 0)

# %%
fig, axs = plt.subplots(1, 3, sharex = True, sharey = True, figsize = (9, 3))
prp = [0, 0.25, 0.50, 0.75, 1]
plt.xlim(0, 1)
plt.ylim(0.97, 1)

# 5% Incidence
y_05_idc = [vals_05_pan, vals_05_025, vals_05_050, vals_05_075, vals_05_100]

#axs[0].plot(prp, y_05_1, marker = '.', color = 'crimson', label = r'rel_p_hh = 1')
axs[0].plot(prp, y_05_idc, marker = '.', color = 'dodgerblue', label = r'$R$')
axs[0].grid()
axs[0].set_title(r'5% Incidence', loc = 'left', size = 10)
axs[0].set_ylabel('$R$')

# 10% Incidence
y_10_idc = [vals_10_pan, vals_10_025, vals_10_050, vals_10_075, vals_10_100]

#axs[1].plot(prp, y_10_1, marker = '.', color = 'crimson', label = r'rel_p_hh = 1')
axs[1].plot(prp, y_10_idc, marker = '.', color = 'dodgerblue', label = r'$R$')
axs[1].grid()
axs[1].set_title(r'10% Incidence', loc = 'left', size = 10)

# 30% Incidence
y_30_idc = [vals_30_pan, vals_30_025, vals_30_050, vals_30_075, vals_30_100]

#axs[2].plot(prp, y_30_1, marker = '.', color = 'crimson', label = r'rel_p_hh = 1')
axs[2].plot(prp, y_30_idc, marker = '.', color = 'dodgerblue', label = r'$R$')
axs[2].grid()
axs[2].set_title(r'30% Incidence', loc = 'left', size = 10)

fig.text(0.5, -0.03, 'Person-to-Person Transmission', ha='center')

handles, labels = axs[0].get_legend_handles_labels()
fig.legend(handles, labels, bbox_to_anchor = (0.65, -0.05), frameon = False, ncol = 3)
fig.tight_layout()

# %%
import numpy as np

# %%
np.genfromtxt('si_dist.txt')
# Out:
# array([0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#        0.0000e+00, 2.0000e-06, 4.0000e-06, 9.0000e-05, 9.3000e-05,
#        8.3900e-04, 5.4300e-04, 3.4880e-03, 1.8770e-03, 8.8900e-03,
#        4.1320e-03, 1.6417e-02, 6.9600e-03, 2.5614e-02, 9.9400e-03,
#        3.4036e-02, 1.2420e-02, 4.1437e-02, 1.4421e-02, 4.5704e-02,
#        1.5933e-02, 4.8421e-02, 1.6111e-02, 4.9372e-02, 1.6258e-02,
#        4.8355e-02, 1.5596e-02, 4.6437e-02, 1.4829e-02, 4.3699e-02,
#        1.3886e-02, 4.0238e-02, 1.2768e-02, 3.6827e-02, 1.1455e-02,
#        3.2915e-02, 1.0404e-02, 2.9358e-02, 9.1370e-03, 2.6219e-02,
#        8.1410e-03, 2.3137e-02, 7.0360e-03, 2.0235e-02, 6.0920e-03,
#        1.7521e-02, 5.5420e-03, 1.5208e-02, 4.6610e-03, 1.3361e-02,
#        4.0520e-03, 1.1460e-02, 3.5760e-03, 9.8150e-03, 2.9880e-03,
#        8.6460e-03, 2.6660e-03, 7.4110e-03, 2.3240e-03, 6.3390e-03,
#        1.9820e-03, 5.5360e-03, 1.6800e-03, 4.8470e-03, 1.4270e-03,
# ...

# %% [markdown]
# # 12 March 2024

# %%
dark_red = '#8C1515'
light_red = '#B83A4B'
black = '#2E2D29'
grey = '#53565A'
blue = 'dodgerblue'

# %% [markdown]
# ### $R_{\rm HH}$ vs $R$ Plots

# %%
vals_05_pan = np.genfromtxt('54/pan/R_HH_05.txt').mean(axis = 0)
vals_05_025 = np.genfromtxt('54/25/R_HH_05.txt').mean(axis = 0)
vals_05_050 = np.genfromtxt('54/50/R_HH_05.txt').mean(axis = 0)
vals_05_075 = np.genfromtxt('54/75/R_HH_05.txt').mean(axis = 0)
vals_05_100 = np.genfromtxt('54/100/R_HH_05.txt').mean(axis = 0)

vals_10_pan = np.genfromtxt('54/pan/R_HH_10.txt').mean(axis = 0)
vals_10_025 = np.genfromtxt('54/25/R_HH_10.txt').mean(axis = 0)
vals_10_050 = np.genfromtxt('54/50/R_HH_10.txt').mean(axis = 0)
vals_10_075 = np.genfromtxt('54/75/R_HH_10.txt').mean(axis = 0)
vals_10_100 = np.genfromtxt('54/100/R_HH_10.txt').mean(axis = 0)

vals_30_pan = np.genfromtxt('54/pan/R_HH_30.txt').mean(axis = 0)
vals_30_025 = np.genfromtxt('54/25/R_HH_30.txt').mean(axis = 0)
vals_30_050 = np.genfromtxt('54/50/R_HH_30.txt').mean(axis = 0)
vals_30_075 = np.genfromtxt('54/75/R_HH_30.txt').mean(axis = 0)
vals_30_100 = np.genfromtxt('54/100/R_HH_30.txt').mean(axis = 0)

# %%
fig, axs = plt.subplots(1, 3, sharex = True, sharey = True, figsize = (9, 3))
prp = [0, 0.25, 0.50, 0.75, 1]
plt.xlim(0, 1)
plt.ylim(0, 0.15)

# 5% Incidence
y_05_idc = [vals_05_pan, vals_05_025, vals_05_050, vals_05_075, vals_05_100]

#axs[0].plot(prp, y_05_1, marker = '.', color = 'crimson', label = r'rel_p_hh = 1')
axs[0].plot(prp, y_05_idc, marker = '.', color = light_red, label = r'$R_{\rm HH}$')
axs[0].grid()
axs[0].set_title(r'5% Incidence', loc = 'left', size = 10)
axs[0].set_ylabel(r'$R_{\rm HH}$')

# 10% Incidence
y_10_idc = [vals_10_pan, vals_10_025, vals_10_050, vals_10_075, vals_10_100]

#axs[1].plot(prp, y_10_1, marker = '.', color = 'crimson', label = r'rel_p_hh = 1')
axs[1].plot(prp, y_10_idc, marker = '.', color = light_red, label = r'$R_{\rm HH}$')
axs[1].grid()
axs[1].set_title(r'10% Incidence', loc = 'left', size = 10)

# 30% Incidence
y_30_idc = [vals_30_pan, vals_30_025, vals_30_050, vals_30_075, vals_30_100]

#axs[2].plot(prp, y_30_1, marker = '.', color = 'crimson', label = r'rel_p_hh = 1')
axs[2].plot(prp, y_30_idc, marker = '.', color = light_red, label = r'$R_{\rm HH}$')
axs[2].grid()
axs[2].set_title(r'30% Incidence', loc = 'left', size = 10)

fig.text(0.5, -0.03, 'Person-to-Person Transmission', ha='center')

handles, labels = axs[0].get_legend_handles_labels()
fig.legend(handles, labels, bbox_to_anchor = (0.56, -0.05), frameon = False, ncol = 3)
fig.tight_layout()
plt.savefig('R_HH_plot.png', dpi = 600, bbox_inches = 'tight', transparent = True)

# %%
vals_05_pan = np.genfromtxt('54/pan/R_05.txt').mean(axis = 0)
vals_05_025 = np.genfromtxt('54/25/R_05.txt').mean(axis = 0)
vals_05_050 = np.genfromtxt('54/50/R_05.txt').mean(axis = 0)
vals_05_075 = np.genfromtxt('54/75/R_05.txt').mean(axis = 0)
vals_05_100 = np.genfromtxt('54/100/R_05.txt').mean(axis = 0)

vals_10_pan = np.genfromtxt('54/pan/R_10.txt').mean(axis = 0)
vals_10_025 = np.genfromtxt('54/25/R_10.txt').mean(axis = 0)
vals_10_050 = np.genfromtxt('54/50/R_10.txt').mean(axis = 0)
vals_10_075 = np.genfromtxt('54/75/R_10.txt').mean(axis = 0)
vals_10_100 = np.genfromtxt('54/100/R_10.txt').mean(axis = 0)

vals_30_pan = np.genfromtxt('54/pan/R_30.txt').mean(axis = 0)
vals_30_025 = np.genfromtxt('54/25/R_30.txt').mean(axis = 0)
vals_30_050 = np.genfromtxt('54/50/R_30.txt').mean(axis = 0)
vals_30_075 = np.genfromtxt('54/75/R_30.txt').mean(axis = 0)
vals_30_100 = np.genfromtxt('54/100/R_30.txt').mean(axis = 0)

# %%
fig, axs = plt.subplots(1, 3, sharex = True, sharey = True, figsize = (9, 3))
prp = [0, 0.25, 0.50, 0.75, 1]
plt.xlim(0, 1)
plt.ylim(0.97, 1)

# 5% Incidence
y_05_idc = [vals_05_pan, vals_05_025, vals_05_050, vals_05_075, vals_05_100]

#axs[0].plot(prp, y_05_1, marker = '.', color = 'crimson', label = r'rel_p_hh = 1')
axs[0].plot(prp, y_05_idc, marker = '.', color = dark_red, label = r'$R$')
axs[0].grid()
axs[0].set_title(r'5% Incidence', loc = 'left', size = 10)
axs[0].set_ylabel('$R$')

# 10% Incidence
y_10_idc = [vals_10_pan, vals_10_025, vals_10_050, vals_10_075, vals_10_100]

#axs[1].plot(prp, y_10_1, marker = '.', color = 'crimson', label = r'rel_p_hh = 1')
axs[1].plot(prp, y_10_idc, marker = '.', color = dark_red, label = r'$R$')
axs[1].grid()
axs[1].set_title(r'10% Incidence', loc = 'left', size = 10)

# 30% Incidence
y_30_idc = [vals_30_pan, vals_30_025, vals_30_050, vals_30_075, vals_30_100]

#axs[2].plot(prp, y_30_1, marker = '.', color = 'crimson', label = r'rel_p_hh = 1')
axs[2].plot(prp, y_30_idc, marker = '.', color = dark_red, label = r'$R$')
axs[2].grid()
axs[2].set_title(r'30% Incidence', loc = 'left', size = 10)

fig.text(0.5, -0.03, 'Person-to-Person Transmission', ha='center')

handles, labels = axs[0].get_legend_handles_labels()
fig.legend(handles, labels, bbox_to_anchor = (0.56, -0.05), frameon = False, ncol = 3)
fig.tight_layout()
plt.savefig('R_plot.png', dpi = 600, bbox_inches = 'tight', transparent = True)

# %% [markdown]
# ## $R_{\rm HH}$ and $R$ Over Time

# %% [markdown]
# ### 5%

# %%
vals_pan_5 = np.genfromtxt('55/pan/R_HH_t_05.txt').reshape(2500, 2, 365)
Hs_pan_5 = np.nanmedian(vals_pan_5[:, 0, :], axis = 0)
Rs_pan_5 = np.nanmedian(vals_pan_5[:, 1, :], axis = 0)

vals_0_5 = np.genfromtxt('55/0/R_HH_t_05.txt').reshape(2500, 2, 365)
Hs_0_5 = np.nanmedian(vals_0_5[:, 0, :], axis = 0)
Rs_0_5 = np.nanmedian(vals_0_5[:, 1, :], axis = 0)

vals_25_5 = np.genfromtxt('55/25/R_HH_t_05.txt').reshape(2500, 2, 365)
Hs_25_5 = np.nanmedian(vals_25_5[:, 0, :], axis = 0)
Rs_25_5 = np.nanmedian(vals_25_5[:, 1, :], axis = 0)

vals_50_5 = np.genfromtxt('55/50/R_HH_t_05.txt').reshape(2500, 2, 365)
Hs_50_5 = np.nanmedian(vals_50_5[:, 0, :], axis = 0)
Rs_50_5 = np.nanmedian(vals_50_5[:, 1, :], axis = 0)

vals_75_5 = np.genfromtxt('55/75/R_HH_t_05.txt').reshape(2500, 2, 365)
Hs_75_5 = np.nanmedian(vals_75_5[:, 0, :], axis = 0)
Rs_75_5 = np.nanmedian(vals_75_5[:, 1, :], axis = 0)

vals_100_5 = np.genfromtxt('55/100/R_HH_t_05.txt').reshape(2500, 2, 365)
Hs_100_5 = np.nanmedian(vals_100_5[:, 0, :], axis = 0)
Rs_100_5 = np.nanmedian(vals_100_5[:, 1, :], axis = 0)
# Out:
# The history saving thread hit an unexpected error (OperationalError('unable to open database file')).History will not be written to the database.

# %%
fig, axs = plt.subplots(1, 2, figsize = (8, 3))

axs[0].plot(np.arange(1, 366), Rs_0_5, label = r'0%')
axs[0].plot(np.arange(1, 366), Rs_25_5, label = r'25%')
axs[0].plot(np.arange(1, 366), Rs_50_5, label = r'50%')
axs[0].plot(np.arange(1, 366), Rs_75_5, label = r'75%')
axs[0].plot(np.arange(1, 366), Rs_100_5, label = r'100%')
axs[0].grid()
axs[0].set_axisbelow(True)
axs[0].set_xlim(0, 365)
axs[0].set_ylim(0, 1)
axs[0].set_xlabel('Day')
axs[0].set_ylabel(r'$R$');

axs[1].plot(np.arange(1, 366), Hs_0_5, label = r'0%')
axs[1].plot(np.arange(1, 366), Hs_25_5, label = r'25%')
axs[1].plot(np.arange(1, 366), Hs_50_5, label = r'50%')
axs[1].plot(np.arange(1, 366), Hs_75_5, label = r'75%')
axs[1].plot(np.arange(1, 366), Hs_100_5, label = r'100%')
axs[1].grid()
axs[1].set_axisbelow(True)
axs[1].set_xlim(0, 365)
axs[1].set_ylim(0, 0.4)
axs[1].set_xlabel('Day')
axs[1].set_ylabel(r'$R_{\rm HH}$')

handles, labels = axs[0].get_legend_handles_labels()
fig.legend(handles, labels, bbox_to_anchor = (0.835, 0.05), frameon = False, ncol = 5)
fig.tight_layout()

plt.savefig('plots/55/time_5.png', dpi = 600, bbox_inches = 'tight', transparent = True)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[76], line 31
#      28 fig.legend(handles, labels, bbox_to_anchor = (0.835, 0.05), frameon = False, ncol = 5)
#      29 fig.tight_layout()
# ---> 31 plt.savefig('plots/55/time_5.png', dpi = 600, bbox_inches = 'tight', transparent = True)
#
# File /usr/local/linux/mambaforge-3.11/lib/python3.11/site-packages/matplotlib/pyplot.py:954, in savefig(*args, **kwargs)
#     951 @_copy_docstring_and_deprecators(Figure.savefig)
#     952 def savefig(*args, **kwargs):
#     953     fig = gcf()
# --> 954     res = fig.savefig(*args, **kwargs)
#     955     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#     956     return res
#
# File /usr/local/linux/mambaforge-3.11/lib/python3.11/site-packages/matplotlib/figure.py:3274, in Figure.savefig(self, fname, transparent, **kwargs)
# ...

# %% [markdown]
# ### 10%

# %%
vals_pan_10 = np.genfromtxt('55/pan/R_HH_t_10.txt').reshape(2500, 2, 365)
Hs_pan_10 = np.nanmedian(vals_pan_10[:, 0, :], axis = 0)
Rs_pan_10 = np.nanmedian(vals_pan_10[:, 1, :], axis = 0)

vals_0_10 = np.genfromtxt('55/0/R_HH_t_10.txt').reshape(2500, 2, 365)
Hs_0_10 = np.nanmedian(vals_0_10[:, 0, :], axis = 0)
Rs_0_10 = np.nanmedian(vals_0_10[:, 1, :], axis = 0)

vals_25_10 = np.genfromtxt('55/25/R_HH_t_10.txt').reshape(2500, 2, 365)
Hs_25_10 = np.nanmedian(vals_25_10[:, 0, :], axis = 0)
Rs_25_10 = np.nanmedian(vals_25_10[:, 1, :], axis = 0)

vals_50_10 = np.genfromtxt('55/50/R_HH_t_10.txt').reshape(2500, 2, 365)
Hs_50_10 = np.nanmedian(vals_50_10[:, 0, :], axis = 0)
Rs_50_10 = np.nanmedian(vals_50_10[:, 1, :], axis = 0)

vals_75_10 = np.genfromtxt('55/75/R_HH_t_10.txt').reshape(2500, 2, 365)
Hs_75_10 = np.nanmedian(vals_75_10[:, 0, :], axis = 0)
Rs_75_10 = np.nanmedian(vals_75_10[:, 1, :], axis = 0)

vals_100_10 = np.genfromtxt('55/100/R_HH_t_10.txt').reshape(2500, 2, 365)
Hs_100_10 = np.nanmedian(vals_100_10[:, 0, :], axis = 0)
Rs_100_10 = np.nanmedian(vals_100_10[:, 1, :], axis = 0)

# %%
fig, axs = plt.subplots(1, 2, figsize = (10, 3))

axs[0].plot(np.arange(1, 366), Rs_0_10, label = r'0%')
axs[0].plot(np.arange(1, 366), Rs_25_10, label = r'25%')
axs[0].plot(np.arange(1, 366), Rs_50_10, label = r'50%')
axs[0].plot(np.arange(1, 366), Rs_75_10, label = r'75%')
axs[0].plot(np.arange(1, 366), Rs_100_10, label = r'100%')
axs[0].grid()
axs[0].set_axisbelow(True)
axs[0].set_xlim(0, 365)
axs[0].set_ylim(0, 1)
axs[0].set_xlabel('Day')
axs[0].set_ylabel(r'$R$');

axs[1].plot(np.arange(1, 366), Hs_0_10, label = r'0%')
axs[1].plot(np.arange(1, 366), Hs_25_10, label = r'25%')
axs[1].plot(np.arange(1, 366), Hs_50_10, label = r'50%')
axs[1].plot(np.arange(1, 366), Hs_75_10, label = r'75%')
axs[1].plot(np.arange(1, 366), Hs_100_10, label = r'100%')
axs[1].grid()
axs[1].set_axisbelow(True)
axs[1].set_xlim(0, 365)
axs[1].set_ylim(0, 0.4)
axs[1].set_xlabel('Day')
axs[1].set_ylabel(r'$R_{\rm HH}$')

handles, labels = axs[0].get_legend_handles_labels()
fig.legend(handles, labels, bbox_to_anchor = (0.835, 0.05), frameon = False, ncol = 5)
fig.tight_layout()

plt.savefig('plots/55/time_10.png', dpi = 600, bbox_inches = 'tight', transparent = True)

# %% [markdown]
# ### 30%

# %%
vals_pan_30 = np.genfromtxt('55/pan/R_HH_t_30.txt').reshape(2500, 2, 365)
Hs_pan_30 = np.nanmedian(vals_pan_30[:, 0, :], axis = 0)
Rs_pan_30 = np.nanmedian(vals_pan_30[:, 1, :], axis = 0)

vals_0_30 = np.genfromtxt('55/0/R_HH_t_30.txt').reshape(2500, 2, 365)
Hs_0_30 = np.nanmedian(vals_0_30[:, 0, :], axis = 0)
Rs_0_30 = np.nanmedian(vals_0_30[:, 1, :], axis = 0)

vals_25_30 = np.genfromtxt('55/25/R_HH_t_30.txt').reshape(2500, 2, 365)
Hs_25_30 = np.nanmedian(vals_25_30[:, 0, :], axis = 0)
Rs_25_30 = np.nanmedian(vals_25_30[:, 1, :], axis = 0)

vals_50_30 = np.genfromtxt('55/50/R_HH_t_30.txt').reshape(2500, 2, 365)
Hs_50_30 = np.nanmedian(vals_50_30[:, 0, :], axis = 0)
Rs_50_30 = np.nanmedian(vals_50_30[:, 1, :], axis = 0)

vals_75_30 = np.genfromtxt('55/75/R_HH_t_30.txt').reshape(2500, 2, 365)
Hs_75_30 = np.nanmedian(vals_75_30[:, 0, :], axis = 0)
Rs_75_30 = np.nanmedian(vals_75_30[:, 1, :], axis = 0)

vals_100_30 = np.genfromtxt('55/100/R_HH_t_30.txt').reshape(2500, 2, 365)
Hs_100_30 = np.nanmedian(vals_100_30[:, 0, :], axis = 0)
Rs_100_30 = np.nanmedian(vals_100_30[:, 1, :], axis = 0)

# %%
fig, axs = plt.subplots(1, 2, figsize = (10, 3))

axs[0].plot(np.arange(1, 366), Rs_0_30, label = r'0%')
axs[0].plot(np.arange(1, 366), Rs_25_30, label = r'25%')
axs[0].plot(np.arange(1, 366), Rs_50_30, label = r'50%')
axs[0].plot(np.arange(1, 366), Rs_75_30, label = r'75%')
axs[0].plot(np.arange(1, 366), Rs_100_30, label = r'100%')
axs[0].grid()
axs[0].set_axisbelow(True)
axs[0].set_xlim(0, 365)
axs[0].set_ylim(0, 1)
axs[0].set_xlabel('Day')
axs[0].set_ylabel(r'$R$');

axs[1].plot(np.arange(1, 366), Hs_0_30, label = r'0%')
axs[1].plot(np.arange(1, 366), Hs_25_30, label = r'25%')
axs[1].plot(np.arange(1, 366), Hs_50_30, label = r'50%')
axs[1].plot(np.arange(1, 366), Hs_75_30, label = r'75%')
axs[1].plot(np.arange(1, 366), Hs_100_30, label = r'100%')
axs[1].grid()
axs[1].set_axisbelow(True)
axs[1].set_xlim(0, 365)
axs[1].set_ylim(0, 0.4)
axs[1].set_xlabel('Day')
axs[1].set_ylabel(r'$R_{\rm HH}$')

handles, labels = axs[0].get_legend_handles_labels()
fig.legend(handles, labels, bbox_to_anchor = (0.835, 0.05), frameon = False, ncol = 5)
fig.tight_layout()

plt.savefig('plots/55/time_30.png', dpi = 600, bbox_inches = 'tight', transparent = True)

# %% [markdown]
# # 25 March 2024

# %% [markdown]
# ## 5%

# %%
vals_pan_5 = np.genfromtxt('56/pan/R_HH_t_05.txt').reshape(2500, 2, 365)
Hs_pan_5 = np.nanmedian(vals_pan_5[:, 0, :], axis = 0)
Rs_pan_5 = np.nanmedian(vals_pan_5[:, 1, :], axis = 0)

vals_0_5 = np.genfromtxt('56/0/R_HH_t_05.txt').reshape(2500, 2, 365)
Hs_0_5 = np.nanmedian(vals_0_5[:, 0, :], axis = 0)
Rs_0_5 = np.nanmedian(vals_0_5[:, 1, :], axis = 0)

vals_25_5 = np.genfromtxt('56/25/R_HH_t_05.txt').reshape(2500, 2, 365)
Hs_25_5 = np.nanmedian(vals_25_5[:, 0, :], axis = 0)
Rs_25_5 = np.nanmedian(vals_25_5[:, 1, :], axis = 0)

vals_50_5 = np.genfromtxt('56/50/R_HH_t_05.txt').reshape(2500, 2, 365)
Hs_50_5 = np.nanmedian(vals_50_5[:, 0, :], axis = 0)
Rs_50_5 = np.nanmedian(vals_50_5[:, 1, :], axis = 0)

vals_75_5 = np.genfromtxt('56/75/R_HH_t_05.txt').reshape(2500, 2, 365)
Hs_75_5 = np.nanmedian(vals_75_5[:, 0, :], axis = 0)
Rs_75_5 = np.nanmedian(vals_75_5[:, 1, :], axis = 0)

vals_100_5 = np.genfromtxt('56/100/R_HH_t_05.txt').reshape(2500, 2, 365)
Hs_100_5 = np.nanmedian(vals_100_5[:, 0, :], axis = 0)
Rs_100_5 = np.nanmedian(vals_100_5[:, 1, :], axis = 0)

# %%
fig, axs = plt.subplots(1, 2, figsize = (8, 3))

axs[0].plot(np.arange(1, 366), Rs_0_5, label = r'0%')
axs[0].plot(np.arange(1, 366), Rs_25_5, label = r'25%')
axs[0].plot(np.arange(1, 366), Rs_50_5, label = r'50%')
axs[0].plot(np.arange(1, 366), Rs_75_5, label = r'75%')
axs[0].plot(np.arange(1, 366), Rs_100_5, label = r'100%')
axs[0].grid()
axs[0].set_axisbelow(True)
axs[0].set_xlim(0, 365)
axs[0].set_ylim(0, 0.6)
axs[0].set_xlabel('Day')
axs[0].set_ylabel(r'$R$');

axs[1].plot(np.arange(1, 366), Hs_0_5, label = r'0%')
axs[1].plot(np.arange(1, 366), Hs_25_5, label = r'25%')
axs[1].plot(np.arange(1, 366), Hs_50_5, label = r'50%')
axs[1].plot(np.arange(1, 366), Hs_75_5, label = r'75%')
axs[1].plot(np.arange(1, 366), Hs_100_5, label = r'100%')
axs[1].grid()
axs[1].set_axisbelow(True)
axs[1].set_xlim(0, 365)
axs[1].set_ylim(0, 0.6)
axs[1].set_xlabel('Day')
axs[1].set_ylabel(r'$R_{\rm HH}$')

handles, labels = axs[0].get_legend_handles_labels()
fig.legend(handles, labels, bbox_to_anchor = (0.835, 0.05), frameon = False, ncol = 5)
fig.tight_layout()

plt.savefig('plots/56/time_5.png', dpi = 600, bbox_inches = 'tight', transparent = True)

# %% [markdown]
# ## 10%

# %%
vals_pan_10 = np.genfromtxt('56/pan/R_HH_t_10.txt').reshape(2500, 2, 365)
Hs_pan_10 = np.nanmedian(vals_pan_10[:, 0, :], axis = 0)
Rs_pan_10 = np.nanmedian(vals_pan_10[:, 1, :], axis = 0)

vals_0_10 = np.genfromtxt('56/0/R_HH_t_10.txt').reshape(2500, 2, 365)
Hs_0_10 = np.nanmedian(vals_0_10[:, 0, :], axis = 0)
Rs_0_10 = np.nanmedian(vals_0_10[:, 1, :], axis = 0)

vals_25_10 = np.genfromtxt('56/25/R_HH_t_10.txt').reshape(2500, 2, 365)
Hs_25_10 = np.nanmedian(vals_25_10[:, 0, :], axis = 0)
Rs_25_10 = np.nanmedian(vals_25_10[:, 1, :], axis = 0)

vals_50_10 = np.genfromtxt('56/50/R_HH_t_10.txt').reshape(2500, 2, 365)
Hs_50_10 = np.nanmedian(vals_50_10[:, 0, :], axis = 0)
Rs_50_10 = np.nanmedian(vals_50_10[:, 1, :], axis = 0)

vals_75_10 = np.genfromtxt('56/75/R_HH_t_10.txt').reshape(2500, 2, 365)
Hs_75_10 = np.nanmedian(vals_75_10[:, 0, :], axis = 0)
Rs_75_10 = np.nanmedian(vals_75_10[:, 1, :], axis = 0)

vals_100_10 = np.genfromtxt('56/100/R_HH_t_10.txt').reshape(2500, 2, 365)
Hs_100_10 = np.nanmedian(vals_100_10[:, 0, :], axis = 0)
Rs_100_10 = np.nanmedian(vals_100_10[:, 1, :], axis = 0)

# %%
fig, axs = plt.subplots(1, 2, figsize = (10, 3))

axs[0].plot(np.arange(1, 366), Rs_0_10, label = r'0%')
axs[0].plot(np.arange(1, 366), Rs_25_10, label = r'25%')
axs[0].plot(np.arange(1, 366), Rs_50_10, label = r'50%')
axs[0].plot(np.arange(1, 366), Rs_75_10, label = r'75%')
axs[0].plot(np.arange(1, 366), Rs_100_10, label = r'100%')
axs[0].grid()
axs[0].set_axisbelow(True)
axs[0].set_xlim(0, 365)
axs[0].set_ylim(0, 0.6)
axs[0].set_xlabel('Day')
axs[0].set_ylabel(r'$R$');

axs[1].plot(np.arange(1, 366), Hs_0_10, label = r'0%')
axs[1].plot(np.arange(1, 366), Hs_25_10, label = r'25%')
axs[1].plot(np.arange(1, 366), Hs_50_10, label = r'50%')
axs[1].plot(np.arange(1, 366), Hs_75_10, label = r'75%')
axs[1].plot(np.arange(1, 366), Hs_100_10, label = r'100%')
axs[1].grid()
axs[1].set_axisbelow(True)
axs[1].set_xlim(0, 365)
axs[1].set_ylim(0, 0.6)
axs[1].set_xlabel('Day')
axs[1].set_ylabel(r'$R_{\rm HH}$')

handles, labels = axs[0].get_legend_handles_labels()
fig.legend(handles, labels, bbox_to_anchor = (0.835, 0.05), frameon = False, ncol = 5)
fig.tight_layout()

plt.savefig('plots/56/time_10.png', dpi = 600, bbox_inches = 'tight', transparent = True)

# %% [markdown]
# ## 30%

# %%
vals_pan_30 = np.genfromtxt('56/pan/R_HH_t_30.txt').reshape(2500, 2, 365)
Hs_pan_30 = np.nanmedian(vals_pan_30[:, 0, :], axis = 0)
Rs_pan_30 = np.nanmedian(vals_pan_30[:, 1, :], axis = 0)

vals_0_30 = np.genfromtxt('56/0/R_HH_t_30.txt').reshape(2500, 2, 365)
Hs_0_30 = np.nanmedian(vals_0_30[:, 0, :], axis = 0)
Rs_0_30 = np.nanmedian(vals_0_30[:, 1, :], axis = 0)

vals_25_30 = np.genfromtxt('56/25/R_HH_t_30.txt').reshape(2500, 2, 365)
Hs_25_30 = np.nanmedian(vals_25_30[:, 0, :], axis = 0)
Rs_25_30 = np.nanmedian(vals_25_30[:, 1, :], axis = 0)

vals_50_30 = np.genfromtxt('56/50/R_HH_t_30.txt').reshape(2500, 2, 365)
Hs_50_30 = np.nanmedian(vals_50_30[:, 0, :], axis = 0)
Rs_50_30 = np.nanmedian(vals_50_30[:, 1, :], axis = 0)

vals_75_30 = np.genfromtxt('56/75/R_HH_t_30.txt').reshape(2500, 2, 365)
Hs_75_30 = np.nanmedian(vals_75_30[:, 0, :], axis = 0)
Rs_75_30 = np.nanmedian(vals_75_30[:, 1, :], axis = 0)

vals_100_30 = np.genfromtxt('56/100/R_HH_t_30.txt').reshape(2500, 2, 365)
Hs_100_30 = np.nanmedian(vals_100_30[:, 0, :], axis = 0)
Rs_100_30 = np.nanmedian(vals_100_30[:, 1, :], axis = 0)

# %%
fig, axs = plt.subplots(1, 2, figsize = (10, 3))

axs[0].plot(np.arange(1, 366), Rs_0_30, label = r'0%')
axs[0].plot(np.arange(1, 366), Rs_25_30, label = r'25%')
axs[0].plot(np.arange(1, 366), Rs_50_30, label = r'50%')
axs[0].plot(np.arange(1, 366), Rs_75_30, label = r'75%')
axs[0].plot(np.arange(1, 366), Rs_100_30, label = r'100%')
axs[0].grid()
axs[0].set_axisbelow(True)
axs[0].set_xlim(0, 365)
axs[0].set_ylim(0, 0.6)
axs[0].set_xlabel('Day')
axs[0].set_ylabel(r'$R$');

axs[1].plot(np.arange(1, 366), Hs_0_30, label = r'0%')
axs[1].plot(np.arange(1, 366), Hs_25_30, label = r'25%')
axs[1].plot(np.arange(1, 366), Hs_50_30, label = r'50%')
axs[1].plot(np.arange(1, 366), Hs_75_30, label = r'75%')
axs[1].plot(np.arange(1, 366), Hs_100_30, label = r'100%')
axs[1].grid()
axs[1].set_axisbelow(True)
axs[1].set_xlim(0, 365)
axs[1].set_ylim(0, 1)
axs[1].set_xlabel('Day')
axs[1].set_ylabel(r'$R_{\rm HH}$')

handles, labels = axs[0].get_legend_handles_labels()
fig.legend(handles, labels, bbox_to_anchor = (0.835, 0.05), frameon = False, ncol = 5)
fig.tight_layout()

plt.savefig('plots/56/time_30.png', dpi = 600, bbox_inches = 'tight', transparent = True)
